// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0"
#r "nuget: Plotly.NET.Interactive, 2.0.0"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=4_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/4_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/4_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.Combine

// %%
histogramContour
// Out:
// <div id="1efddd44-ac6e-4198-9809-78fd8d966f4e" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_1efddd44ac6e4198980978fd8d966f4e = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-0.8602703978587007,-1.5716820168428969,-0.8061613491277148,-1.351713231560614,-0.5725313739180571,-1.0279305287542684,-1.4201690622225853,-0.9763059983445603,-1.3223246504883932,-0.433637889698945,0.058546947130786675,-0.2847382033950139,-0.19436421376732294,-1.284369672277794,-0.719193177060786,-0.2677198204175282,-1.0647420645312118,0.022211019426274237,-1.462012121411623,-0.08093942807746246,-0.8561073953941204,0.1488974965170854,-0.20387664067976952,-0.9587017180803554,-1.4674678031729398,-1.7249883490284315,-0.8295852746632191,-0.6796544384454913,-0.3996658713081084,0.47364879118125736,-1.2779914130704233,-1.0961968852074573,-0.05672132268641883,-0.25351991605247615,-1.1951876711302174,-0.41859371998148226,-1.361297094090438,-1.7261155871331675,-0.4876132359008997,-1.9332190876643558,-0.9871247081239573,0.9088593599886442,-1.7649577682417776,-0.4674784793076971,-1.2915153904120218,-1.0206206869727281,-0.37557967566626627,-0.3242795629898172,-1.5553673118884954,-1.0399262441093344,-0.034568130511933526,-0.7082645742279898,-1.6402870005077332,-0.17685644621117436,-0.26620611520381,-0.980544849144683,-0.6223392146671929,-1.0321879180621665,-1.8084523817015412,-0.7849020214533603,-0.8776955819269807,-1.5263385417294173,-1.0782920256953208,-0.6747128011038588,-0.46364222816948986,-0.07925362387360468,-1.942062566566634,-0.7013573970353836,-0.30478111082334386,-1.8602002492693566,-0.8744700515628959,-0.6380580824206676,-0.5814382197887866,-0.6088185835777464,-1.0253923359163415,-1.7932675111216556,-0.7085492919032066,0.4580184980322213,-1.3058708574948126,-0.7008971151123513,-2.0044596010235645,-1.7312195923187788,0.07526305106730746,-1.0778828835925691,-0.8895026148387369,-0.9523568830026287,-0.6823577124085258,-0.44206685721139855,-0.8121581424221515,-1.8848220644755835,-1.0412759425873546,-2.1679677084138906,-1.309529518002722,-0.8187110447763173,-0.7073599154204064,-1.06864162488017,-1.5778851704817258,0.1718044040305855,0.5570122133798876,0.13548335858287985,-0.691912848960221,-0.6329370890561766,-1.6551819069289453,-0.32722687683957424,-1.6939284962499193,-1.3640211454032674,-1.373173300246421,-0.6175680733475047,-0.6534722358654822,-1.2315203967392723,-1.3384735927138935,-0.4198933744515019,-0.7217026731050226,-1.628147848149514,-0.8112545148091943,-0.40643286308080995,-1.020798937835138,-0.7992188765344499,-0.05241468210128586,1.0899608864479366,0.07540662550959987,-0.9179276250003725,-0.44140020668548413,-1.5577898923345566,-1.1072400190332903,0.008298524091736592,-0.3142686453513163,-1.7428065060519096,-0.6710997989506775,-0.6283588733737996,-0.9709180481141646,0.2868867489083098,-0.1887525607275466,-0.4931596571006736,-0.005842562946714369,0.20268698833561316,-0.8275163618836595,0.22128526263545356,0.2583937352698499,0.024193237733251105,-1.6157057562475463,0.355978439702221,-0.4767693529119755,-1.329896656565729,-0.7672412796175607,-0.333510276825242,-0.12849888272345233,0.24796955625239214,-0.9316581077603956,-0.02112801260041952,-0.3189092135394756,-1.2611067443613027,-0.7308029143708564,-0.7695832339166421,-0.3225446522151014,-0.7392423976829109,0.07551608130874743,-0.6945187628150771,-0.3497063159337086,0.44021648409478265,1.0928113963969723,-0.45673381114776723,-0.14105380861580658,-0.9067460534352172,0.47442612827467256,-1.3453267885264717,-0.6251435879100508,-0.5997126316670939,0.6178178961181223,-0.47778960091606326,-0.8666618515007026,-1.0125815284744146,-0.9809439277388798,-0.569571434736916,-1.1833 ...

// %%
let histogram2d = 
    Chart.Histogram2d (x,y)

// %%
histogram2d
// Out:
// <div id="782075bc-dbbc-4916-8d81-134c13c4ad0a" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_782075bcdbbc49168d81134c13c4ad0a = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2d","x":[-0.8602703978587007,-1.5716820168428969,-0.8061613491277148,-1.351713231560614,-0.5725313739180571,-1.0279305287542684,-1.4201690622225853,-0.9763059983445603,-1.3223246504883932,-0.433637889698945,0.058546947130786675,-0.2847382033950139,-0.19436421376732294,-1.284369672277794,-0.719193177060786,-0.2677198204175282,-1.0647420645312118,0.022211019426274237,-1.462012121411623,-0.08093942807746246,-0.8561073953941204,0.1488974965170854,-0.20387664067976952,-0.9587017180803554,-1.4674678031729398,-1.7249883490284315,-0.8295852746632191,-0.6796544384454913,-0.3996658713081084,0.47364879118125736,-1.2779914130704233,-1.0961968852074573,-0.05672132268641883,-0.25351991605247615,-1.1951876711302174,-0.41859371998148226,-1.361297094090438,-1.7261155871331675,-0.4876132359008997,-1.9332190876643558,-0.9871247081239573,0.9088593599886442,-1.7649577682417776,-0.4674784793076971,-1.2915153904120218,-1.0206206869727281,-0.37557967566626627,-0.3242795629898172,-1.5553673118884954,-1.0399262441093344,-0.034568130511933526,-0.7082645742279898,-1.6402870005077332,-0.17685644621117436,-0.26620611520381,-0.980544849144683,-0.6223392146671929,-1.0321879180621665,-1.8084523817015412,-0.7849020214533603,-0.8776955819269807,-1.5263385417294173,-1.0782920256953208,-0.6747128011038588,-0.46364222816948986,-0.07925362387360468,-1.942062566566634,-0.7013573970353836,-0.30478111082334386,-1.8602002492693566,-0.8744700515628959,-0.6380580824206676,-0.5814382197887866,-0.6088185835777464,-1.0253923359163415,-1.7932675111216556,-0.7085492919032066,0.4580184980322213,-1.3058708574948126,-0.7008971151123513,-2.0044596010235645,-1.7312195923187788,0.07526305106730746,-1.0778828835925691,-0.8895026148387369,-0.9523568830026287,-0.6823577124085258,-0.44206685721139855,-0.8121581424221515,-1.8848220644755835,-1.0412759425873546,-2.1679677084138906,-1.309529518002722,-0.8187110447763173,-0.7073599154204064,-1.06864162488017,-1.5778851704817258,0.1718044040305855,0.5570122133798876,0.13548335858287985,-0.691912848960221,-0.6329370890561766,-1.6551819069289453,-0.32722687683957424,-1.6939284962499193,-1.3640211454032674,-1.373173300246421,-0.6175680733475047,-0.6534722358654822,-1.2315203967392723,-1.3384735927138935,-0.4198933744515019,-0.7217026731050226,-1.628147848149514,-0.8112545148091943,-0.40643286308080995,-1.020798937835138,-0.7992188765344499,-0.05241468210128586,1.0899608864479366,0.07540662550959987,-0.9179276250003725,-0.44140020668548413,-1.5577898923345566,-1.1072400190332903,0.008298524091736592,-0.3142686453513163,-1.7428065060519096,-0.6710997989506775,-0.6283588733737996,-0.9709180481141646,0.2868867489083098,-0.1887525607275466,-0.4931596571006736,-0.005842562946714369,0.20268698833561316,-0.8275163618836595,0.22128526263545356,0.2583937352698499,0.024193237733251105,-1.6157057562475463,0.355978439702221,-0.4767693529119755,-1.329896656565729,-0.7672412796175607,-0.333510276825242,-0.12849888272345233,0.24796955625239214,-0.9316581077603956,-0.02112801260041952,-0.3189092135394756,-1.2611067443613027,-0.7308029143708564,-0.7695832339166421,-0.3225446522151014,-0.7392423976829109,0.07551608130874743,-0.6945187628150771,-0.3497063159337086,0.44021648409478265,1.0928113963969723,-0.45673381114776723,-0.14105380861580658,-0.9067460534352172,0.47442612827467256,-1.3453267885264717,-0.6251435879100508,-0.5997126316670939,0.6178178961181223,-0.47778960091606326,-0.8666618515007026,-1.0125815284744146,-0.9809439277388798,-0.569571434736916,-1.18335085677 ...
