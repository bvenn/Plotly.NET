// %% [markdown]
// // can't yet format YamlFrontmatter (["title: 2D Histograms"; "category: Distribution Charts"; "categoryindex: 5"; "index: 4"], Some { StartLine = 2 StartColumn = 0 EndLine = 6 EndColumn = 8 }) to pynb markdown

// %%
#r "nuget: Plotly.NET, 2.0.0"
#r "nuget: Plotly.NET.Interactive, 2.0.0"

// %% [markdown]
// # 2D Histograms
//
// [![Binder](https://plotly.net/img/badge-binder.svg)](https://mybinder.org/v2/gh/plotly/Plotly.NET/gh-pages?filepath=4_4_2d-histograms.ipynb)&emsp;
// [![Script](https://plotly.net/img/badge-script.svg)](https://plotly.net/4_4_2d-histograms.fsx)&emsp;
// [![Notebook](https://plotly.net/img/badge-notebook.svg)](https://plotly.net/4_4_2d-histograms.ipynb)
//
// *Summary:* This example shows how to create a bi-dimensional histogram of two data samples in F#.
//
// let's first create some data for the purpose of creating example charts:

// %%
open Plotly.NET 

//---------------------- generate random normally distributed data ---------------------- 
let normal (rnd:System.Random) mu tau =
    let mutable v1 = 2.0 * rnd.NextDouble() - 1.0
    let mutable v2 = 2.0 * rnd.NextDouble() - 1.0
    let mutable r = v1 * v1 + v2 * v2
    while (r >= 1.0 || r = 0.0) do
        v1 <- 2.0 * rnd.NextDouble() - 1.0
        v2 <- 2.0 * rnd.NextDouble() - 1.0
        r <- v1 * v1 + v2 * v2
    let fac = sqrt(-2.0*(log r)/r)
    (tau * v1 * fac + mu)

let rnd = System.Random()
let n = 2000
let a = -1.
let b = 1.2
let step i = a +  ((b - a) / float (n - 1)) * float i

//---------------------- generate data distributed in x and y direction ---------------------- 
let x = Array.init n (fun i -> ((step i)**3.) + (0.3 * (normal (rnd) 0. 2.) ))
let y = Array.init n (fun i -> ((step i)**6.) + (0.3 * (normal (rnd) 0. 2.) ))

// %% [markdown]
// A Histogram2d chart can be created using the `Chart.Histogram2d` or `Chart.Histogram2dContour` functions.

// %%
let histogramContour =
    [
        Chart.Histogram2dContour (x,y,Line=Line.init(Width=0.))
        Chart.Point(x,y,Opacity=0.3)
    ]
    |> Chart.Combine

// %%
histogramContour
// Out:
// <div id="e5a8218f-8d43-48d0-a892-b63a6a08a434" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_e5a8218f8d4348d0a892b63a6a08a434 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2dcontour","x":[-1.4729490624432262,-1.6811737458992324,-0.7723832633855708,-1.305646076919758,-1.763043433846381,-0.9339583318077398,-1.1275757785546128,-1.5775102562508931,-1.1845497074313198,-1.5338188608546182,-0.3059494834397839,-1.5071904549513837,-0.3668445194089126,-0.6691593960048452,-2.039480169137562,-1.4777329384813096,-0.9087281554407917,0.1965025769756502,-1.3944523570052656,-0.44867169336794305,-0.36376269508077386,-0.8309107895303575,-0.33480520798636404,-0.7773148162652099,-1.194060258116872,-1.2265640447288702,-0.8591722764670121,-1.273475184761554,-2.5178498618010843,-1.7925775903874486,-1.8998820860882013,-1.5296319630310315,-0.01883299825259277,-0.6369864059832959,-1.2492360650565772,-0.8608942215152372,-1.7486232203858405,0.26365664867397387,-0.9164700370135552,-0.31607705410494535,-1.4492747066099165,-0.7914576245757682,-1.9214895468962316,-0.23451539740138938,-0.2138369315236397,-0.33631444825851586,0.014155812185448813,0.38922042690581604,-1.5680223175608206,-1.2024189170899324,-1.1536051798766096,-0.030547674001836556,-1.764536396194696,0.6881801639534373,-1.5489213757795106,-1.1719598870398158,-0.5751343297164823,-0.9101780521431636,-0.5641912424698106,-0.2896095729848579,-0.7239254264376564,-1.0230977890148556,1.088235758149993,-1.3381481810791322,-0.12519409280448934,-0.5010079076308629,-0.7755477657651443,-0.8184875613543521,0.030828680520019636,0.02735011877980742,-0.8024792246095671,-0.5428195394542543,-1.5420395307446157,-1.23356202606382,0.3895884677743121,-0.3302049198549354,-0.827891308953217,-0.14758684663177735,-0.8291945086203187,-0.44855459622174354,0.07402008147974193,0.057616433558842384,-0.31233477719420516,-1.0382157921088284,-0.45044485250765204,-1.071831563332831,-0.4595455734961883,-0.7059113286031672,-1.4946144835486561,-0.39303116203016064,-0.581737531601962,-1.2580364407846871,-1.3271928757611577,-0.8313342311890899,-0.9254740954641155,-1.3386251623661165,-0.4080001739882337,-0.8220920931573255,-0.9332963464158499,-1.2385798329327584,-0.46898538631043796,-0.3915176406090625,8.066132149131544E-05,-0.535887238103946,-0.8454907958265505,0.03589491608150741,-1.3170390793186117,0.23528539372864965,-0.44358087437183535,-0.5990588824339595,0.42077398160821544,-0.7539181309865983,0.05622043192056925,-0.561034194932105,-1.8342192206044041,-0.2894267843804227,-1.0739278863543795,-0.4227056175596904,-0.04974683014897163,-0.5063941992662766,-0.07373168697429666,0.09730926894043024,-0.8075289269388993,-1.8577676382028092,-0.41248921732153104,-0.2417035139744092,-0.447525327766989,-1.0494669316465217,-0.0249583913472734,-0.16166516402098746,-0.37097495604493375,0.02935930225390171,-1.1449948325585946,-0.6975683445910953,-0.8600692936906759,-1.0586777239232985,-0.8116233663575431,-0.36090177286517927,-0.0423223467543421,-1.8791713227398086,-0.6694117381726319,-0.14370327608255062,-0.23642167419859123,0.3431695442741818,0.18061714053803868,-0.6144152322004118,-0.41234654399579296,0.15678053255276647,0.24634124946165215,-0.3958314071966531,-0.3848751117287489,0.9077955135879471,-0.6602340741372572,0.12050003804632226,-0.6377211798591902,-0.15706555306314485,-0.6364635956502593,-0.6345645621029568,-0.30987894685704426,-0.5337767563113645,-0.4429847838011441,-0.3921774129580593,-0.03226434128270805,0.06565107516745916,-0.19779914292083506,0.014336974047906015,-0.3586647077569425,0.5019090446516425,0.0008124157189131065,-1.5305856181948234,-0.30442221139363534,-0.773031162967048,-0.46972283715379093,-1.7103 ...

// %%
let histogram2d = 
    Chart.Histogram2d (x,y)

// %%
histogram2d
// Out:
// <div id="59a280df-5d93-480e-9253-d370ce9a5fd1" style="width: 600px; height: 600px;"><!-- Plotly chart will be drawn inside this DIV --></div><script type="text/javascript">            var renderPlotly_59a280df5d93480e9253d370ce9a5fd1 = function() {            var fsharpPlotlyRequire = requirejs.config({context:'fsharp-plotly',paths:{plotly:'https://cdn.plot.ly/plotly-latest.min'}}) || require;            fsharpPlotlyRequire(['plotly'], function(Plotly) {            var data = [{"type":"histogram2d","x":[-1.4729490624432262,-1.6811737458992324,-0.7723832633855708,-1.305646076919758,-1.763043433846381,-0.9339583318077398,-1.1275757785546128,-1.5775102562508931,-1.1845497074313198,-1.5338188608546182,-0.3059494834397839,-1.5071904549513837,-0.3668445194089126,-0.6691593960048452,-2.039480169137562,-1.4777329384813096,-0.9087281554407917,0.1965025769756502,-1.3944523570052656,-0.44867169336794305,-0.36376269508077386,-0.8309107895303575,-0.33480520798636404,-0.7773148162652099,-1.194060258116872,-1.2265640447288702,-0.8591722764670121,-1.273475184761554,-2.5178498618010843,-1.7925775903874486,-1.8998820860882013,-1.5296319630310315,-0.01883299825259277,-0.6369864059832959,-1.2492360650565772,-0.8608942215152372,-1.7486232203858405,0.26365664867397387,-0.9164700370135552,-0.31607705410494535,-1.4492747066099165,-0.7914576245757682,-1.9214895468962316,-0.23451539740138938,-0.2138369315236397,-0.33631444825851586,0.014155812185448813,0.38922042690581604,-1.5680223175608206,-1.2024189170899324,-1.1536051798766096,-0.030547674001836556,-1.764536396194696,0.6881801639534373,-1.5489213757795106,-1.1719598870398158,-0.5751343297164823,-0.9101780521431636,-0.5641912424698106,-0.2896095729848579,-0.7239254264376564,-1.0230977890148556,1.088235758149993,-1.3381481810791322,-0.12519409280448934,-0.5010079076308629,-0.7755477657651443,-0.8184875613543521,0.030828680520019636,0.02735011877980742,-0.8024792246095671,-0.5428195394542543,-1.5420395307446157,-1.23356202606382,0.3895884677743121,-0.3302049198549354,-0.827891308953217,-0.14758684663177735,-0.8291945086203187,-0.44855459622174354,0.07402008147974193,0.057616433558842384,-0.31233477719420516,-1.0382157921088284,-0.45044485250765204,-1.071831563332831,-0.4595455734961883,-0.7059113286031672,-1.4946144835486561,-0.39303116203016064,-0.581737531601962,-1.2580364407846871,-1.3271928757611577,-0.8313342311890899,-0.9254740954641155,-1.3386251623661165,-0.4080001739882337,-0.8220920931573255,-0.9332963464158499,-1.2385798329327584,-0.46898538631043796,-0.3915176406090625,8.066132149131544E-05,-0.535887238103946,-0.8454907958265505,0.03589491608150741,-1.3170390793186117,0.23528539372864965,-0.44358087437183535,-0.5990588824339595,0.42077398160821544,-0.7539181309865983,0.05622043192056925,-0.561034194932105,-1.8342192206044041,-0.2894267843804227,-1.0739278863543795,-0.4227056175596904,-0.04974683014897163,-0.5063941992662766,-0.07373168697429666,0.09730926894043024,-0.8075289269388993,-1.8577676382028092,-0.41248921732153104,-0.2417035139744092,-0.447525327766989,-1.0494669316465217,-0.0249583913472734,-0.16166516402098746,-0.37097495604493375,0.02935930225390171,-1.1449948325585946,-0.6975683445910953,-0.8600692936906759,-1.0586777239232985,-0.8116233663575431,-0.36090177286517927,-0.0423223467543421,-1.8791713227398086,-0.6694117381726319,-0.14370327608255062,-0.23642167419859123,0.3431695442741818,0.18061714053803868,-0.6144152322004118,-0.41234654399579296,0.15678053255276647,0.24634124946165215,-0.3958314071966531,-0.3848751117287489,0.9077955135879471,-0.6602340741372572,0.12050003804632226,-0.6377211798591902,-0.15706555306314485,-0.6364635956502593,-0.6345645621029568,-0.30987894685704426,-0.5337767563113645,-0.4429847838011441,-0.3921774129580593,-0.03226434128270805,0.06565107516745916,-0.19779914292083506,0.014336974047906015,-0.3586647077569425,0.5019090446516425,0.0008124157189131065,-1.5305856181948234,-0.30442221139363534,-0.773031162967048,-0.46972283715379093,-1.71036755421 ...
